# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = BASE_DIR / "data" / "processed"

DATA_DIR
# Out:
# PosixPath('/Users/fabrica/Documents/ia-futebol-brasil/data/processed')

# %%
brasileirao_path = DATA_DIR / "brasileirao_serie_a_clean.csv"
copa_path = DATA_DIR / "copa_brasil_clean.csv"

df_brasileirao = pd.read_csv(brasileirao_path)
df_copa = pd.read_csv(copa_path)

df_brasileirao.shape, df_copa.shape
# Out:
# ((8453, 41), (598, 44))

# %%
df_brasileirao.head()
# Out:
#    ano_campeonato data  rodada                             estadio arbitro  \
# 0            2003  NaN       1  Estádio Brinco de Ouro da Princesa     NaN
# 1            2003  NaN       1  Estádio Governador Magalhães Pinto     NaN
# 2            2003  NaN       1      Estádio Jornalista Mário Filho     NaN
# 3            2003  NaN       1  Estádio Governador Plácido Castelo     NaN
# 4            2003  NaN       1           Estádio de Hailé Pinheiro     NaN
#
#    publico  publico_max time_mandante time_visitante tecnico_mandante  ...  \
# 0      NaN          NaN       Guarani  Vasco da Gama              NaN  ...
# 1      NaN          NaN      Cruzeiro    São Caetano              NaN  ...
# 2      NaN          NaN      Flamengo    Coritiba FC              NaN  ...
# 3      NaN          NaN     Fortaleza       EC Bahia              NaN  ...
# 4      NaN          NaN      Goiás EC    Paysandu SC              NaN  ...
#
#   chutes_mandante  chutes_visitante  chutes_fora_mandante  \
# ...

# %%
df_brasileirao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8453 entries, 0 to 8452
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ano_campeonato                  8453 non-null   int64
#  1   data                            3286 non-null   object
#  2   rodada                          8453 non-null   int64
#  3   estadio                         8442 non-null   object
#  4   arbitro                         6743 non-null   object
#  5   publico                         6742 non-null   float64
#  6   publico_max                     4181 non-null   float64
#  7   time_mandante                   8453 non-null   object
#  8   time_visitante                  8453 non-null   object
#  9   tecnico_mandante                6299 non-null   object
#  10  tecnico_visitante               6299 non-null   object
#  11  colocacao_mandante              6743 non-null   float64
# ...

# %%
df_copa.head()
# Out:
#    ano_campeonato        data   horario             fase   tipo_fase  \
# 0            2020  2020-05-02  14:30:00  1ª Eliminatória  Jogo Único
# 1            2020  2020-05-02  15:30:00  1ª Eliminatória  Jogo Único
# 2            2020  2020-05-02  18:15:00  1ª Eliminatória  Jogo Único
# 3            2020  2020-05-02  19:30:00  1ª Eliminatória  Jogo Único
# 4            2020  2020-05-02  19:30:00  1ª Eliminatória  Jogo Único
#
#                                              estadio arbitro  publico  \
# 0                 Estádio Municipal Gerson do Amaral     NaN      703
# 1                          Estádio Bruno José Daniel     NaN      992
# 2  Estádio Municipal Vereador Benedito Laurindo d...     NaN      832
# 3                       Estádio Barão da Serra Negra     NaN     2126
# 4                      Estádio Arnaldo Lopes Martins     NaN     1044
#
#    publico_max  time_mandante  ... chutes_mandante chutes_visitante  \
# ...

# %%
df_copa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ano_campeonato                  598 non-null    int64
#  1   data                            255 non-null    object
#  2   horario                         598 non-null    object
#  3   fase                            598 non-null    object
#  4   tipo_fase                       598 non-null    object
#  5   estadio                         597 non-null    object
#  6   arbitro                         175 non-null    object
#  7   publico                         598 non-null    int64
#  8   publico_max                     553 non-null    float64
#  9   time_mandante                   598 non-null    object
#  10  time_visitante                  598 non-null    object
#  11  tecnico_mandante                390 non-null    object
# ...

# %%
df_brasileirao["ano_campeonato"].value_counts().sort_index()
# Out:
# ano_campeonato
# 2003    456
# 2004    456
# 2005    418
# 2006    380
# 2007    380
# 2008    380
# 2009    380
# 2010    380
# 2011    380
# 2012    380
# 2013    380
# 2014    380
# 2015    380
# 2016    380
# 2017    380
# 2018    380
# 2019    380
# 2020    380
# 2021    380
# 2022    380
# 2023    380
# 2024    283
# Name: count, dtype: int64

# %%
df_copa["ano_campeonato"].value_counts().sort_index()
# Out:
# ano_campeonato
# 2020    120
# 2021    122
# 2022    122
# 2023    122
# 2024    112
# Name: count, dtype: int64

# %%
sorted(
    set(df_brasileirao["time_mandante"].unique()).union(
        set(df_brasileirao["time_visitante"].unique())
    )
)[:20]  # mostra só os 20 primeiros
# Out:
# ['América-MG',
#  'América-RN',
#  'Athletico-PR',
#  'Atlético-GO',
#  'Atlético-MG',
#  'Atlético-PR',
#  'Avaí FC',
#  'Barueri',
#  'Botafogo',
#  'Brasiliense-DF',
#  'CSA',
#  'Ceará SC',
#  'Chapecoense',
#  'Corinthians',
#  'Coritiba FC',
#  'Criciúma EC',
#  'Cruzeiro',
#  'Cuiabá-MT',
#  'EC Bahia',
#  'EC Vitória']

# %%
sorted(
    set(df_copa["time_mandante"].unique()).union(
        set(df_copa["time_visitante"].unique())
    )
)[:20]
# Out:
# ['4 de Julho',
#  'ABC FC',
#  'AD Bahia-BA',
#  'ASA',
#  'Afogados',
#  'Altos',
#  'Amazonas',
#  'América-MG',
#  'América-RN',
#  'Anápolis',
#  'Aparecidense',
#  'Aquidauanense',
#  'Athletic',
#  'Athletico-PR',
#  'Atl. Acreano',
#  'Atl. Alagoinhas',
#  'Atlético-GO',
#  'Atlético-MG',
#  'Audax-RJ',
#  'Avaí FC']
